# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
studName = ['Aisha', 'titi', 'Shehu', 'Kabir', 'Biola']
mathScore = [69, 99, 78, 90, 89]
engScore = [78, 70, 67, 66, 75]
bioScore = [89, 77, 76, 90, 87]
chemScore = [87, 76, 66, 99, 89]

studRec = pd.DataFrame()

# %%
studRec
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
studRec['Name'] = studName
studRec['Math'] = mathScore
studRec['Eng'] = engScore
studRec['Bio'] = bioScore
studRec['Chem'] = chemScore

print(studRec)
# Out:
#     Name  Math  Eng  Bio  Chem
# 0  Aisha    69   78   89    87
# 1   titi    99   70   77    76
# 2  Shehu    78   67   76    66
# 3  Kabir    90   66   90    99
# 4  Biola    89   75   87    89

# %%
studRec.to_csv('c:/datasets/newDf.csv')

# %%
df = pd.read_csv('c:/datasets/newDf.csv')

# %%
df2 = df[['Name', 'Math']]

# %%
df2
# Out:
#     Name  Math
# 0  Aisha    69
# 1   titi    99
# 2  Shehu    78
# 3  Kabir    90
# 4  Biola    89

# %%
df_new = pd.read_csv('c:/datasets/Sales.csv')

# %%
df_new
# Out:
#         SalesId  StoreId  ProductId        Date  UnitPrice  Quantity
# 0         82319    22726        590  2019-12-02     0.0525        93
# 1         15022    21754        390  2017-11-19     5.1100        28
# 2         11624    71053        883  2020-07-13     7.3675        33
# 3         63101    22914        658  2019-05-12     2.0825        76
# 4         29702    22623        632  2020-07-20     0.6475         8
# ...         ...      ...        ...         ...        ...       ...
# 199995    57660    85123        682  2019-07-01     4.4625        75
# 199996    18783    22727        656  2017-04-18     1.6800        30
# 199997    25064    22912        831  2019-06-10     2.5025        60
# 199998    43683    22622        902  2018-08-06     3.2025        98
# 199999    44211    22749        775  2018-06-22     1.8550        32
#
# [200000 rows x 6 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   SalesId    200000 non-null  int64
#  1   StoreId    200000 non-null  int64
#  2   ProductId  200000 non-null  int64
#  3   Date       200000 non-null  object
#  4   UnitPrice  200000 non-null  float64
#  5   Quantity   200000 non-null  int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 8.4+ MB

# %%
df_new.describe()
# Out:
#              SalesId        StoreId      ProductId      UnitPrice  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean    49997.590185   33720.734235     500.587255       3.313406
# std     23095.103021   23209.383882     288.611347       2.812360
# min     10000.000000   10002.000000       1.000000       0.017500
# 25%     29959.000000   21791.000000     250.000000       1.277500
# 50%     50048.000000   22728.000000     501.000000       2.765000
# 75%     70043.000000   22960.000000     751.000000       4.287500
# max     90000.000000   85123.000000    1000.000000      21.157500
#
#             Quantity
# count  200000.000000
# mean       50.383910
# std        28.870702
# min         1.000000
# 25%        25.000000
# 50%        50.000000
# 75%        75.000000
# max       100.000000

# %%
df_new['UnitPrice'].plot(kind='density')
sb.boxplot(df_new['UnitPrice'])
# Out:
# C:\Users\koas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UnitPrice', ylabel='Density'>

# %%
df_new['Quantity'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4 = pd.read_csv('c:/datasets/titanic/train.csv')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df4['Survived'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4['Pclass'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sb

# %%
sb.boxplot(df['Pclass'])
# Out:
# C:\Users\koas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass'>

# %%
df4.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df5 = df4[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin','Embarked']].where(df4['Survived']==1, df4[['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin','Embarked']].values)

# %%
df5
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Age       714 non-null    object
#  2   Fare      891 non-null    object
#  3   SibSp     891 non-null    int64
#  4   Cabin     204 non-null    object
#  5   Embarked  889 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 27.9+ KB

# %%
df5.describe()
# Out:
#            Pclass       SibSp
# count  891.000000  891.000000
# mean     2.308642    0.523008
# std      0.836071    1.102743
# min      1.000000    0.000000
# 25%      2.000000    0.000000
# 50%      3.000000    0.000000
# 75%      3.000000    1.000000
# max      3.000000    8.000000

# %%
print(df5)
# Out:
#      Pclass   Age     Fare  SibSp Cabin Embarked
# 0         3  22.0     7.25      1   NaN        S
# 1         1  38.0  71.2833      1   C85        C
# 2         3  26.0    7.925      0   NaN        S
# 3         1  35.0     53.1      1  C123        S
# 4         3  35.0     8.05      0   NaN        S
# ..      ...   ...      ...    ...   ...      ...
# 886       2  27.0     13.0      0   NaN        S
# 887       1  19.0     30.0      0   B42        S
# 888       3   NaN    23.45      1   NaN        S
# 889       1  26.0     30.0      0  C148        C
# 890       3  32.0     7.75      0   NaN        Q
#
# [891 rows x 6 columns]

# %%
sb.boxplot(df5['SibSp'])
# Out:
# C:\Users\koas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %%
df5['SibSp'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
titanExtract = df5

# %%
titanExtract.to_csv('c:/datasets/titanic/titanExtract.csv')

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', 6)
print(df5)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare            Cabin Embarked
# 0              1         0       3  ...      7.25              NaN        S
# 1              2         1       1  ...   71.2833              C85        C
# 2              3         1       3  ...     7.925              NaN        S
# 3              4         1       1  ...      53.1             C123        S
# 4              5         0       3  ...      8.05              NaN        S
# 5              6         0       3  ...    8.4583              NaN        Q
# 6              7         0       1  ...   51.8625              E46        S
# 7              8         0       3  ...    21.075              NaN        S
# 8              9         1       3  ...   11.1333              NaN        S
# 9             10         1       2  ...   30.0708              NaN        C
# 10            11         1       3  ...      16.7               G6        S
# ...

# %%
sb.boxplot(df5['Age'])
# Out:
# C:\Users\koas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df4
# Out:
#      PassengerId  Survived  Pclass  ...      Fare            Cabin  Embarked
# 0              1         0       3  ...    7.2500              NaN         S
# 1              2         1       1  ...   71.2833              C85         C
# 2              3         1       3  ...    7.9250              NaN         S
# 3              4         1       1  ...   53.1000             C123         S
# 4              5         0       3  ...    8.0500              NaN         S
# 5              6         0       3  ...    8.4583              NaN         Q
# 6              7         0       1  ...   51.8625              E46         S
# 7              8         0       3  ...   21.0750              NaN         S
# 8              9         1       3  ...   11.1333              NaN         S
# 9             10         1       2  ...   30.0708              NaN         C
# 10            11         1       3  ...   16.7000               G6         S
# ...

# %%
df4.where(df4['Survived']==0, df4)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare            Cabin  Embarked
# 0              1         0       3  ...    7.2500              NaN         S
# 1              2         1       1  ...   71.2833              C85         C
# 2              3         1       3  ...    7.9250              NaN         S
# 3              4         1       1  ...   53.1000             C123         S
# 4              5         0       3  ...    8.0500              NaN         S
# 5              6         0       3  ...    8.4583              NaN         Q
# 6              7         0       1  ...   51.8625              E46         S
# 7              8         0       3  ...   21.0750              NaN         S
# 8              9         1       3  ...   11.1333              NaN         S
# 9             10         1       2  ...   30.0708              NaN         C
# 10            11         1       3  ...   16.7000               G6         S
# ...

# %%
class Dog:    
    def woof(self):
        return 'woof!'

t = Dog()
t.woof()
# Out:
# 'woof!'

# %%
boardgames = [
  'Rivals for Catan',
  '7 Wonders Duel',
  'Carcassonne',
  'Hive',
]

boardgames.append('Patchwork')

print(boardgames)
# Out:
# ['Rivals for Catan', '7 Wonders Duel', 'Carcassonne', 'Hive', 'Patchwork']

# %%
def hours_to_seconds(hours):
    return hours * 60 * 60

hours_to_seconds(8)
# Out:
# 28800

# %%
class Building:
    
    def __init__(self, number):
        self.number = number

b = Building(245)

b.number
# Out:
# 245

# %%
def time_to_seconds(hours, minutes):
    print(hours * 60 * 60 + minutes * 60)

time_to_seconds(1,50)
# Out:
# 6600

# %%
def add(a, b):
    return a + b

x = add(1, 2)

x
# Out:
# 3

# %%
numbers = [9, 2, 5, 11, 4, 3]

largest = max(numbers)

print(largest)
# Out:
# 11

# %%
def double_number(n):
    return n * 2

double_number(4)
# Out:
# 8

# %%
class Dog:
    def __init__(self):
        pass
    
    def bark(self):
        return "bark bark bark bark bark bark..."

d = Dog()
d.bark()
# Out:
# 'bark bark bark bark bark bark...'

# %%
letters = ['a', 'b', 'c']
for ii in enumerate(letters):
    print(ii, ": ", x)
# Out:
# (0, 'a') :  (0, 'a')
# (1, 'b') :  (0, 'a')
# (2, 'c') :  (0, 'a')

# %%
class Planet:
    def __init__(self, name):
        self.name = name
        
m = Planet('mercury')

m.name
# Out:
# 'mercury'

# %%
class Planet:
    def __init__(self, name):
        self.name = name
        
v = Planet('venus')

v.name
# Out:
# 'venus'

# %%
class Candy:
    flavor = 'sweet'
    
    def __init__(self, name):
        self.name = name
        
c = Candy('Chocolate')

c.name
# Out:
# 'Chocolate'
