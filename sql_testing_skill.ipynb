# %%
import pandas as pd
import sqlite3
import os

# %%
os.chdir('c:/sandbox')

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///newdbase.db

# %%
# %sql CREATE TABLE employee (id INT(10) NOT NULL, FNAME VARCHA(35) NOT NULL, LNAME VARCHAR(35) NOT NULL, DEPARTMENT VARCHA(15), PRIMARY KEY(id));
# Out:
#  * sqlite:///newdbase.db
# Done.
# []

# %%
# %sql INSERT INTO employee (id, FNAME, LNAME, DEPARTMENT) VALUES (1, 'KAYBEE', 'SADIQ', 'IT'),(2, 'KB', 'SADIKU', 'INFOTECH')
# Out:
#  * sqlite:///newdbase.db
# 2 rows affected.
# []

# %%
# %sql SELECT * FROM employee
# Out:
#  * sqlite:///newdbase.db
# Done.
# [(1, 'KAYBEE', 'SADIQ', 'IT'), (2, 'KB', 'SADIKU', 'INFOTECH')]

# %%
# %sql sqlite:///flights.db

# %%
# %sql SELECT * FROM sqlite_master WHERE type = 'table'
# Out:
#  * sqlite:///flights.db
#    sqlite:///newdbase.db
# Done.
# [('table', 'airports', 'airports', 2, 'CREATE TABLE airports (\n[index] INTEGER,\n  [id] TEXT,\n  [name] TEXT,\n  [city] TEXT,\n  [country] TEXT,\n  [code] TEXT,\n  [icao] TEXT,\n  [latitude] TEXT,\n  [longitude] TEXT,\n  [altitude] TEXT,\n  [offset] TEXT,\n  [dst] TEXT,\n  [timezone] TEXT\n)'),
#  ('table', 'airlines', 'airlines', 945, 'CREATE TABLE airlines (\n[index] INTEGER,\n  [id] TEXT,\n  [name] TEXT,\n  [alias] TEXT,\n  [iata] TEXT,\n  [icao] TEXT,\n  [callsign] TEXT,\n  [country] TEXT,\n  [active] TEXT\n)'),
#  ('table', 'routes', 'routes', 1393, 'CREATE TABLE routes (\n[index] INTEGER,\n  [airline] TEXT,\n  [airline_id] TEXT,\n  [source] TEXT,\n  [source_id] TEXT,\n  [dest] TEXT,\n  [dest_id] TEXT,\n  [codeshare] TEXT,\n  [stops] TEXT,\n  [equipment] TEXT\n)')]

# %%
path = 'c:/sandbox/flights.db'
conn = sqlite3.connect(path)

# %%
df = pd.read_sql_query('SELECT * FROM ROUTES', conn)

# %%
df.head()
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %%
df2 = pd.read_sql_query('SELECT * FROM airlines', conn)

# %%
df2.head()
# Out:
#    index id                                          name alias  iata  icao  \
# 0      0  1                                Private flight    \N     -  None
# 1      1  2                                   135 Airways    \N  None   GNL
# 2      2  3                                 1Time Airline    \N    1T   RNX
# 3      3  4  2 Sqn No 1 Elementary Flying Training School    \N  None   WYT
# 4      4  5                               213 Flight Unit    \N  None   TFU
#
#   callsign         country active
# 0     None            None      Y
# 1  GENERAL   United States      N
# 2  NEXTIME    South Africa      Y
# 3     None  United Kingdom      N
# 4     None          Russia      N

# %%
query = 'SELECT airlines.*, routes.dest FROM airlines JOIN routes ON routes.airline_id=airlines.id WHERE routes.source="ASF"'
result = pd.read_sql_query(query, conn)

# %%
result
# Out:
#    index    id                       name           alias iata icao  \
# 0    409   410                 Aerocondor              \N   2B  ARD
# 1    409   410                 Aerocondor              \N   2B  ARD
# 2   3539  3545          Moskovia Airlines              \N   3R  GAI
# 3   3539  3545          Moskovia Airlines              \N   3R  GAI
# 4   4831  4840                   Scat Air            None   DV  VSV
# 5   4320  4329                S7 Airlines  Sibir Airlines   S7  SBI
# 6    129   130  Aeroflot Russian Airlines              \N   SU  AFL
# 7   4940  4951           Turkish Airlines              \N   TK  THY
#
#             callsign     country active dest
# 0         AEROCONDOR    Portugal      Y  KZN
# 1         AEROCONDOR    Portugal      Y  MRV
# 2     GROMOV AIRLINE      Russia      Y  DME
# 3     GROMOV AIRLINE      Russia      Y  LED
# 4             VLASTA  Kazakhstan      Y  SCO
# 5  SIBERIAN AIRLINES      Russia      Y  DME
# ...

# %%
query = pd.read_sql_query('SELECT * FROM routes LIMIT 10', conn)
query
# Out:
#    index airline airline_id source source_id dest dest_id codeshare stops  \
# 0      0      2B        410    AER      2965  KZN    2990      None     0
# 1      1      2B        410    ASF      2966  KZN    2990      None     0
# 2      2      2B        410    ASF      2966  MRV    2962      None     0
# 3      3      2B        410    CEK      2968  KZN    2990      None     0
# 4      4      2B        410    CEK      2968  OVB    4078      None     0
# 5      5      2B        410    DME      4029  KZN    2990      None     0
# 6      6      2B        410    DME      4029  NBC    6969      None     0
# 7      7      2B        410    DME      4029  TGK      \N      None     0
# 8      8      2B        410    DME      4029  UUA    6160      None     0
# 9      9      2B        410    EGO      6156  KGD    2952      None     0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2
# 5       CR2
# 6       CR2
# 7       CR2
# 8       CR2
# 9       CR2

# %%
query2 = pd.read_sql_query('SELECT COUNT(*) FROM airlines  WHERE country = "Portugal"', conn)
query2
# Out:
#    COUNT(*)
# 0        45
