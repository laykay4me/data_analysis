# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('c:/datasets/WarehouseOrders.csv')

# %%
df
# Out:
#       order_id  customer_id  warehouse_id  order_date shipper_date
# 0          789         3731          8118  01/01/2019   01/04/2019
# 1          790         3486          8118    1/1/2019     1/4/2019
# 2          791         2623          8118    1/1/2019     1/4/2019
# 3          792         9869          8118    1/1/2019     1/4/2019
# 4          793         6866          8118    1/1/2019     1/4/2019
# ...        ...          ...           ...         ...          ...
# 9994     10783         8554          9080  12/30/2019     1/2/2020
# 9995     10784         6439          6509  12/30/2019     1/2/2020
# 9996     10785         4379          6509  12/30/2019     1/2/2020
# 9997     10786         1799          6509  12/30/2019     1/2/2020
# 9998     10787         8469          4338  12/30/2019     1/2/2020
#
# [9999 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      9999 non-null   int64
#  1   customer_id   9999 non-null   int64
#  2   warehouse_id  9999 non-null   int64
#  3   order_date    9999 non-null   object
#  4   shipper_date  9999 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 312.5+ KB

# %%
df.describe().T
# Out:
#                count         mean          std     min     25%     50%  \
# order_id      9999.0  5788.000000  2886.607005   789.0  3288.5  5788.0
# customer_id   9999.0  5470.125813  2601.663953  1001.0  3206.0  5455.0
# warehouse_id  9999.0  5556.591559  2532.789050  1543.0  2666.0  6509.0
#
#                  75%      max
# order_id      8287.5  10787.0
# customer_id   7709.5   9999.0
# warehouse_id  8118.0   9080.0

# %%
df['customer_id'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2 = pd.read_csv('c:/datasets/Movie-Data.csv')

# %%
df2
# Out:
#                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
df2.describe().T
# Out:
#               count unique                                                top  \
# Movie Title     508    508                                10 Cloverfield Lane
# Release Date    508    330                                         2015-12-25
# Wikipedia URL   508    508  https://en.wikipedia.org/wiki/10_Cloverfield_Lane
# Genre           508     17                                             Action
# Director (1)    508    414                                         David Ayer
# Director (2)     41     39                                       Chris Miller
# Cast (1)        508    345                                         Tom Cruise
# Cast (2)        503    402                                        Gary Oldman
# Cast (3)        485    412                                         Rose Byrne
# Cast (4)        452    407                                     Anthony Mackie
# Cast (5)        389    353                                         Ray Liotta
# ...
