# %%
import pandas as pd
import os

# %%
os.chdir('c:/sandbox')

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///sqlite-sakila.db

# %%
# %sql SELECT * FROM sqlite_master WHERE type = 'table'
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.
# [('table', 'actor', 'actor', 2, 'CREATE TABLE actor (\n  actor_id numeric NOT NULL ,\n  first_name VARCHAR(45) NOT NULL,\n  last_name VARCHAR(45) NOT NULL,\n  last_update TIMESTAMP NOT NULL,\n  PRIMARY KEY  (actor_id)\n  )'),
#  ('table', 'country', 'country', 5, 'CREATE TABLE country (\n  country_id SMALLINT NOT NULL,\n  country VARCHAR(50) NOT NULL,\n  last_update TIMESTAMP,\n  PRIMARY KEY  (country_id)\n)'),
#  ('table', 'city', 'city', 7, 'CREATE TABLE city (\n  city_id int NOT NULL,\n  city VARCHAR(50) NOT NULL,\n  country_id SMALLINT NOT NULL,\n  last_update TIMESTAMP NOT NULL,\n  PRIMARY KEY  (city_id),\n  CONSTRAINT fk_city_country FOREIGN KEY (country_id) REFERENCES country (country_id) ON DELETE NO ACTION ON UPDATE CASCADE\n)'),
# ...

# %%
result = %sql SELECT * FROM actor # to save query to result
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.

# %%
df = result.DataFrame() # to convert result to pandas dataframe so that data wrangling can be done
df.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2021-03-06 15:51:59
# 1         2       NICK      WAHLBERG  2021-03-06 15:51:59
# 2         3         ED         CHASE  2021-03-06 15:51:59
# 3         4   JENNIFER         DAVIS  2021-03-06 15:51:59
# 4         5     JOHNNY  LOLLOBRIGIDA  2021-03-06 15:51:59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   actor_id     200 non-null    int64
#  1   first_name   200 non-null    object
#  2   last_name    200 non-null    object
#  3   last_update  200 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 4.0+ KB

# %%
# %sql SELECT * FROM customer LIMIT 10
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.
# [(1, 1, 'MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org', 5, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (2, 1, 'PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 6, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (3, 1, 'LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org', 7, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (4, 2, 'BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org', 8, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (5, 1, 'ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org', 9, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (6, 2, 'JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 10, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
#  (7, 1, 'MARIA', 'MILLER', 'MARIA.MILLER@sakilacustomer.org', 11, '1', '2006-02-14 22:04:36.000', '2021-03-06 15:53:36'),
# ...

# %%
# %sql SELECT * FROM city LIMIT 10
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.
# [(1, 'A Corua (La Corua)', 87, '2021-03-06 15:51:49'),
#  (2, 'Abha', 82, '2021-03-06 15:51:49'),
#  (3, 'Abu Dhabi', 101, '2021-03-06 15:51:49'),
#  (4, 'Acua', 60, '2021-03-06 15:51:49'),
#  (5, 'Adana', 97, '2021-03-06 15:51:49'),
#  (6, 'Addis Abeba', 31, '2021-03-06 15:51:49'),
#  (7, 'Aden', 107, '2021-03-06 15:51:49'),
#  (8, 'Adoni', 44, '2021-03-06 15:51:49'),
#  (9, 'Ahmadnagar', 44, '2021-03-06 15:51:49'),
#  (10, 'Akishima', 50, '2021-03-06 15:51:49')]

# %%
# %sql SELECT * FROM address LIMIT 10
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.
# [(1, '47 MySakila Drive', None, ' ', 300, None, ' ', '2021-03-06 15:51:54'),
#  (2, '28 MySQL Boulevard', None, ' ', 576, None, ' ', '2021-03-06 15:51:54'),
#  (3, '23 Workhaven Lane', None, ' ', 300, None, ' ', '2021-03-06 15:51:54'),
#  (4, '1411 Lillydale Drive', None, ' ', 576, None, ' ', '2021-03-06 15:51:54'),
#  (5, '1913 Hanoi Way', None, ' ', 463, '35200', ' ', '2021-03-06 15:51:54'),
#  (6, '1121 Loja Avenue', None, ' ', 449, '17886', ' ', '2021-03-06 15:51:54'),
#  (7, '692 Joliet Street', None, ' ', 38, '83579', ' ', '2021-03-06 15:51:54'),
#  (8, '1566 Inegl Manor', None, ' ', 349, '53561', ' ', '2021-03-06 15:51:54'),
#  (9, '53 Idfu Parkway', None, ' ', 361, '42399', ' ', '2021-03-06 15:51:54'),
#  (10, '1795 Santiago de Compostela Way', None, ' ', 295, '18743', ' ', '2021-03-06 15:51:54')]

# %%
#Using Join and alais to query database and save in result
result2 = %sql SELECT c.first_name, c.last_name, a.address FROM customer AS c JOIN address AS a ON a.address_id = c.address_id WHERE c.store_id = 1
# Out:
#  * sqlite:///sqlite-sakila.db
# Done.

# %%
df = result2.DataFrame()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326 entries, 0 to 325
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  326 non-null    object
#  1   last_name   326 non-null    object
#  2   address     326 non-null    object
# dtypes: object(3)
# memory usage: 3.9+ KB

# %%
df.head()
# Out:
#   first_name last_name                             address
# 0       MARY     SMITH                      1913 Hanoi Way
# 1   PATRICIA   JOHNSON                    1121 Loja Avenue
# 2      LINDA  WILLIAMS                   692 Joliet Street
# 3  ELIZABETH     BROWN                     53 Idfu Parkway
# 4      MARIA    MILLER  900 Santiago de Compostela Parkway

# %%
df.to_csv('c:/sandbox/testFile.csv')  # to save query as .csv dataframe
