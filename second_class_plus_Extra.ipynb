# %%
import pandas as pd # This is used to import pandas while pd is just an alais

# %%
fileName = 'diabetes.csv'
filePath = 'C:/datasets' # Notice how the backward slash is change to forward slash, else there will be error

# %%
fullFilePath = filePath + '/' + fileName # This is used to load the datafile

# %%
fullFilePath
# Out:
# 'C:/datasets/diabetes.csv'

# %%
df = pd.read_csv(fullFilePath) #df is used to load the file

# %%
df
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
print(df)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
df.info() # this is run to missing values and structural information about the datafile
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 101.6+ KB

# %%
df.describe() # This is used to understand the data behaviour
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
df.describe().T # T transpose the row to column and the column to row
# Out:
#             count           mean           std    min       25%      50%  \
# ID         1000.0     340.500000  2.403977e+02    1.0    125.75    300.5
# No_Pation  1000.0  270551.408000  3.380758e+06  123.0  24063.75  34395.5
# AGE        1000.0      53.528000  8.799241e+00   20.0     51.00     55.0
# Urea       1000.0       5.124743  2.935165e+00    0.5      3.70      4.6
# Cr         1000.0      68.943000  5.998475e+01    6.0     48.00     60.0
# HbA1c      1000.0       8.281160  2.534003e+00    0.9      6.50      8.0
# Chol       1000.0       4.862820  1.301738e+00    0.0      4.00      4.8
# TG         1000.0       2.349610  1.401176e+00    0.3      1.50      2.0
# HDL        1000.0       1.204750  6.604136e-01    0.2      0.90      1.1
# LDL        1000.0       2.609790  1.115102e+00    0.3      1.80      2.5
# VLDL       1000.0       1.854700  3.663599e+00    0.1      0.70      0.9
# BMI        1000.0      29.578020  4.962388e+00   19.0     26.00     30.0
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['HbA1c'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
Sname = ['kaybee', 'ik', 'shehu', 'sodiq', 'sinmi']
mathScore = [70, 60, 90, 88, 78]
bioScore = [60, 55, 70, 68, 40]
chemScore = [50, 70, 58, 78, 60]

studRec = pd.DataFrame() # This is buiding a dataframe (table) in python

# %%
studRec['Name'] = Sname
studRec['math'] = mathScore
studRec['bio'] = bioScore
studRec['chem'] = chemScore

print(studRec)
# Out:
#      Name  math  bio  chem
# 0  kaybee    70   60    50
# 1      ik    60   55    70
# 2   shehu    90   70    58
# 3   sodiq    88   68    78
# 4   sinmi    78   40    60

# %%
studRec.to_csv('c:/datasets/studRec.csv') # to_csv is used to save csv file

# %%
df = pd.read_csv('c:/datasets/studRec.csv')

# %%
df
# Out:
#    Unnamed: 0    Name  math  bio  chem
# 0           0  kaybee    70   60    50
# 1           1      ik    60   55    70
# 2           2   shehu    90   70    58
# 3           3   sodiq    88   68    78
# 4           4   sinmi    78   40    60

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'math', 'bio', 'chem'], dtype='object')

# %%
subdf = df[['Name', 'math', 'bio', 'chem']]

# %%
subdf
# Out:
#      Name  math  bio  chem
# 0  kaybee    70   60    50
# 1      ik    60   55    70
# 2   shehu    90   70    58
# 3   sodiq    88   68    78
# 4   sinmi    78   40    60
